# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("pokemon.csv")
data
# Out:
#       Unnamed: 0                                          image_url    Id  \
# 0              0  https://img.pokemondb.net/sprites/sword-shield...     1
# 1              1  https://img.pokemondb.net/sprites/sword-shield...     2
# 2              2  https://img.pokemondb.net/sprites/sword-shield...     3
# 3              3  https://img.pokemondb.net/sprites/sword-shield...     3
# 4              4  https://img.pokemondb.net/sprites/sword-shield...     4
# ...          ...                                                ...   ...
# 1189        1189  https://img.pokemondb.net/sprites/scarlet-viol...  1006
# 1190        1190  https://img.pokemondb.net/sprites/scarlet-viol...  1007
# 1191        1191  https://img.pokemondb.net/sprites/scarlet-viol...  1008
# 1192        1192  https://img.pokemondb.net/sprites/scarlet-viol...  1009
# 1193        1193  https://img.pokemondb.net/sprites/scarlet-viol...  1010
#
#                        Names     Type1     Type2  Total   HP  Attack  Defense  \
# ...

# %%
#to check the last 5 rows of our dataset
data.tail()
# Out:
#       Unnamed: 0                                          image_url    Id  \
# 1189        1189  https://img.pokemondb.net/sprites/scarlet-viol...  1006
# 1190        1190  https://img.pokemondb.net/sprites/scarlet-viol...  1007
# 1191        1191  https://img.pokemondb.net/sprites/scarlet-viol...  1008
# 1192        1192  https://img.pokemondb.net/sprites/scarlet-viol...  1009
# 1193        1193  https://img.pokemondb.net/sprites/scarlet-viol...  1010
#
#              Names     Type1     Type2  Total   HP  Attack  Defense  Sp. Atk  \
# 1189  Iron Valiant     Fairy  Fighting    590   74     130       90      120
# 1190      Koraidon  Fighting    Dragon    670  100     135      115       85
# 1191      Miraidon  Electric    Dragon    670  100      85      100      135
# 1192  Walking Wake     Water    Dragon    590   99      83       91      125
# 1193   Iron Leaves     Grass   Psychic    590   90     130       88       70
#
#       Sp. Def  Speed
# 1189       60    116
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1194 entries, 0 to 1193
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1194 non-null   int64
#  1   image_url   1194 non-null   object
#  2   Id          1194 non-null   int64
#  3   Names       1194 non-null   object
#  4   Type1       1194 non-null   object
#  5   Type2       652 non-null    object
#  6   Total       1194 non-null   int64
#  7   HP          1194 non-null   int64
#  8   Attack      1194 non-null   int64
#  9   Defense     1194 non-null   int64
#  10  Sp. Atk     1194 non-null   int64
#  11  Sp. Def     1194 non-null   int64
#  12  Speed       1194 non-null   int64
# dtypes: int64(9), object(4)
# memory usage: 121.4+ KB

# %% [markdown]
# >The basic insights we draw from here is that we have a sum of 9 integer type column values and 4 of object type.

# %%
 #Let's have a check on some columns for how many unique elements they contain.
for i in ['Type1','Type2']:
    print("{} => {}".format(i,data[i].unique()))
# Out:
# Type1 => ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Dark' 'Poison' 'Electric' 'Ground'
#  'Ice' 'Fairy' 'Steel' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Dragon'
#  'Flying']
# Type2 => ['Poison' nan 'Flying' 'Dragon' 'Normal' 'Psychic' 'Steel' 'Ground'
#  'Fairy' 'Grass' 'Rock' 'Fighting' 'Electric' 'Ice' 'Dark' 'Ghost' 'Fire'
#  'Water' 'Bug']

# %%
#Let's have a check for Null or NaN values in our dataset. Am sure there must be many...

data.isnull().sum()
# Out:
# Unnamed: 0      0
# image_url       0
# Id              0
# Names           0
# Type1           0
# Type2         542
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# dtype: int64

# %% [markdown]
# >So we got a lot of missing data in column named "Type2" i.e.542.

# %%
#since not all pokemons has Type2 ability,we will fill it with"none"

data['Type2'].fillna('None', inplace=True)
data
# Out:
#       Unnamed: 0                                          image_url    Id  \
# 0              0  https://img.pokemondb.net/sprites/sword-shield...     1
# 1              1  https://img.pokemondb.net/sprites/sword-shield...     2
# 2              2  https://img.pokemondb.net/sprites/sword-shield...     3
# 3              3  https://img.pokemondb.net/sprites/sword-shield...     3
# 4              4  https://img.pokemondb.net/sprites/sword-shield...     4
# ...          ...                                                ...   ...
# 1189        1189  https://img.pokemondb.net/sprites/scarlet-viol...  1006
# 1190        1190  https://img.pokemondb.net/sprites/scarlet-viol...  1007
# 1191        1191  https://img.pokemondb.net/sprites/scarlet-viol...  1008
# 1192        1192  https://img.pokemondb.net/sprites/scarlet-viol...  1009
# 1193        1193  https://img.pokemondb.net/sprites/scarlet-viol...  1010
#
#                        Names     Type1     Type2  Total   HP  Attack  Defense  \
# ...

# %%
#to check if the blanks are filled
data.isnull().sum()
# Out:
# Unnamed: 0    0
# image_url     0
# Id            0
# Names         0
# Type1         0
# Type2         0
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# dtype: int64

# %% [markdown]
# there are no empty cells no more

# %% [markdown]
# # Data Analysis and Visualizations

# %%
#to check the stat that correlates with the other
data.corr()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3352\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#             Unnamed: 0        Id     Total        HP    Attack   Defense  \
# Unnamed: 0    1.000000  0.999857  0.133470  0.145878  0.119155  0.077235
# Id            0.999857  1.000000  0.132872  0.145485  0.118687  0.076291
# Total         0.133470  0.132872  1.000000  0.655285  0.732234  0.636058
# HP            0.145878  0.145485  0.655285  1.000000  0.462873  0.324407
# Attack        0.119155  0.118687  0.732234  0.462873  1.000000  0.469496
# Defense       0.077235  0.076291  0.636058  0.324407  0.469496  1.000000
# Sp. Atk       0.078613  0.077844  0.720425  0.350712  0.335788  0.224284
# Sp. Def       0.067199  0.066349  0.719565  0.389081  0.270501  0.533784
# ...

# %%
fig,axes = plt.subplots(figsize=(14,8))
sns.heatmap(data.corr(),annot=True).set_title('General Stats')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_3352\1867596547.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True).set_title('General Stats')

# %% [markdown]
# ##### here in general stats we can see that:
# >Total has a good correlation with the attack and defence attributes. For example,
#
# >Total with attack: 0.73
#
# >Total with sp.attack: 0.72
#
# >Total with defense: 0.64
#
# >Total with sp.defense: 0.72
#
# >The statement suggests that the "Total" attribute of Pokémon has a strong positive correlation with both the attack and defense attributes. The correlation coefficients provided indicate the strength and direction of the relationship between the "Total" attribute and each specific attribute.
#
# >In this case, a correlation coefficient of 0.73 between the "Total" attribute and attack attribute suggests a relatively strong positive relationship. Similarly, a correlation coefficient of 0.72 between the "Total" attribute and sp.attack (special attack) as well as sp.defense (special defense) attributes also indicates a strong positive relationship.
#
# >However, the correlation coefficient of 0.64 between the "Total" attribute and defense attribute suggests a slightly weaker positive relationship compared to the other attributes.
#
# >Overall, these correlations suggest that as the "Total" attribute of a Pokémon increases, there tends to be a corresponding increase in the attack, special attack, and special defense attributes. The defense attribute, while still positively correlated, may have a slightly weaker relationship with the "Total" attribute.

# %%
#How speed of Pokemon relates to various base factors?

fig,axes = plt.subplots(2,2,figsize=(16,10),sharey=True)
sns.scatterplot(data['Attack'],data['Speed'],ax=axes[0,0])
axes[0,0].set_title("Speed V/S Attack")
sns.scatterplot(data['Defense'],data['Speed'],ax=axes[0,1])
axes[0,1].set_title("Speed V/S Defence")
sns.scatterplot(data['HP'],data['Speed'],ax=axes[1,0])
axes[1,0].set_title("Speed V/S HP")
fig.suptitle("Speed Factor", size=20)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##### Some insights that we can get from the above graphs are:
#
#   ##### ATTACK
# >A pokemon's attack capacity slightly depends on its speed
# >some of the pokemons like mewtwo mega mewtwo X have moderate speed but a good attack capacity,
# >some are very fast yet lacking in their attack capacity.
#
#    ##### DEFENSE
# >For a pokemon's defense speed is not that much required
# >from the above Speed vs Defence plot that, pokemon's which are slower possess more defense capacity.
# >e.g Eternatus Eternamax has high defense of 250 but low speed of 130
#
#    ##### HITPOINT
# >the hitpoint of a pokemon highly affects its speed
# >from the speed vs HP plot, pokemons with high HP possess less speed
# >e.g Blissey with high HP of 255 has a speed of 55.

# %%
#What are the most wide spread types of pokemon



fig,axes = plt.subplots(2,2,figsize=(16,9))
ax = sns.countplot(x='Type1',data=data,order=data['Type1'].value_counts().iloc[:5].index, ax=axes[0,0])
ax.set_title('Type1 pokemon with the widest spread')
for p in ax.patches:
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))

ax = sns.countplot(x='Type2',data=data,order=data['Type2'].value_counts().iloc[:5].index, ax=axes[0,1])
ax.set_title('Type2 pokemons with the widest spread')
for p in ax.patches:
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))

ax = sns.countplot(x='Type1',data=data,order=data['Type1'].value_counts(ascending=True).index[:5], ax=axes[1,0])
ax.set_title('Type1 pokemons with lowest spread')

for p in ax.patches:
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))

ax = sns.countplot(x='Type2',data=data,order=data['Type2'].value_counts(ascending=True).index[:5], ax=axes[1,1])
ax.set_title('Type2 pokemons with lowest spread')
for p in ax.patches:
    ax.annotate('{:.1f}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))
plt.show()

# %% [markdown]
# ##### The most wide spread type of pokemon in:
# > Type1 = Water type pokemons
#
# > Type2 = Flying type pokemons (as this is a type2 so most of the pokemon has no type2)
#
# #####  The least spread type of pokemon in:
# > Type1 = Flying type pokemons
# >Type2 = Bug type pokemons
#
# Note that while there are most number of pokemons with Flying type in thier type2 yet the flying type has the least number in type1.

# %%
#Which type is the strongest overall?

top5_pokemon_Total = data.sort_values(by="Total", ascending=False).reset_index()[:5]
plt.figure(figsize=(15,8))
ax = sns.barplot(x=top5_pokemon_Total["Names"], y=top5_pokemon_Total["Total"], orient='v')
ax.set_title("Which is the best pokémon?", size=20)
ax.set(xlabel="Total", ylabel="Names")
for p in ax.patches:
    ax.annotate('{:.1f}'.format( p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))

# %% [markdown]
# From above plot,comparing all the base strengths,we have Eternatus Eternamax at highest strength,followed by mewtwo mega mewtwo X.
# To determine the strongest Pokemon, we summed up the base statistics for each species.
# While our metric approached Pokemon strength objectively as possible, in the end, it may not be meaningful to all players.
#
# Therefore, the player's selection of moves, attack and defense points during the battle is ultimately a bigger factor
# in determining success than the strength of the Pokemon chosen. And hence the developers have made Pokemon a game that is more
# than simply optimizing statistics and strength, but is a tactical and personal experience.

# %%
 #Which pokemon is the weakest?
buttom5_pokemon_Total = data.sort_values(by="Total", ascending=True).reset_index()[:5]
plt.figure(figsize=(15,8))
ax = sns.barplot(x=buttom5_pokemon_Total["Names"], y=buttom5_pokemon_Total["Total"], orient='v')
ax.set_title("Which is the weakest pokémon?", size=20)
ax.set(xlabel="Total", ylabel="Names")
for p in ax.patches:
    ax.annotate('{:.1f}'.format( p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))

# %% [markdown]
# From above plot,comparing all the base strengths,we have Wishiwashi solo form at lowest strength,followed by sunkem. To determine the strongest Pokemon, we summed up the base statistics for each species.
